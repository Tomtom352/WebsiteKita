# %%
from google.colab import drive
drive.mount('/content/drives/')
# Out:
# Drive already mounted at /content/drives/; to attempt to forcibly remount, call drive.mount("/content/drives/", force_remount=True).

# %%
import cv2
from google.colab.patches import cv2_imshow
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/harimau.jpg', cv2.IMREAD_UNCHANGED)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x750 at 0x7F61C4DBE880>

# %%
print(img.shape)
# Out:
# (750, 1000, 3)

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
img=cv2.imread('/content/drives/MyDrive/Colab Notebooks/harimau.jpg', cv2.IMREAD_GRAYSCALE)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=1000x750 at 0x7F61C4C540D0>

# %%
print(img.shape)
# Out:
# (750, 1000)

# %%
cv2.imwrite ('/content/drives/MyDrive/Colab Notebooks/harimaugrayscale.jpg',img)
# Out:
# True
